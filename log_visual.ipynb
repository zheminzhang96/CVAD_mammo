# %%
import pydicom 
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2
from PIL import Image

# %%
img = Image.open(r'/mnt/storage/breast_cancer_kaggle/logs/try/fake_samples_try.png')

# %%
#fake_image = img.imread('/mnt/storage/breast_cancer_kaggle/logs/try/fake_samples_try.png')
plt.imshow(img)
plt.show()

# %%
real_image = Image.open('/mnt/storage/breast_cancer_kaggle/logs/try/real_samples_try.png')
plt.imshow(real_image)
plt.show()

# %%
f = open("/mnt/storage/breast_cancer_kaggle/logs/try/log_CVAD_0.txt", "r")
print(f.read())
# Out:
# 2023-09-21 15:00:34,023 - root - INFO - Log file is /mnt/storage/breast_cancer_kaggle/logs/try/log_CVAD_0.txt
# 2023-09-21 15:00:34,023 - root - INFO - Data path is ./
# 2023-09-21 15:00:34,023 - root - INFO - Dataset: try
# 2023-09-21 15:00:34,023 - root - INFO - Net Name: CVAD
# 2023-09-21 15:00:34,023 - root - INFO - CVAE Conv capacity: 4
# 2023-09-21 15:00:34,023 - root - INFO - image channel: 1
# 2023-09-21 15:00:34,023 - root - INFO - ------------Stage-1--------------
# 2023-09-21 15:00:34,023 - root - INFO - CVAE batchsize: 64
# 2023-09-21 15:00:34,023 - root - INFO - CVAE epochs: 100
# 2023-09-21 15:00:34,023 - root - INFO - CVAE optimizer: adam
# 2023-09-21 15:00:34,023 - root - INFO - CVAE lr: 0.000100
# 2023-09-21 15:00:34,023 - root - INFO - CVAE weight_decay: 0.000001
# 2023-09-21 15:00:34,023 - root - INFO - CVAE load_model: False
# 2023-09-21 15:00:34,023 - root - INFO - CVAE variational_beta: 1.000000
# ...
