# %%
import pydicom 
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import numpy as np
import os

# %%
path = '/mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/'
patient_list = os.listdir(path)
patient_list
# Out:
# ['24608',
#  '14814',
#  '2460',
#  '292',
#  '59008',
#  '9989',
#  '34192',
#  '1948',
#  '44136',
#  '3915']

# %%
for i in patient_list:
    patient_path = os.path.join(path, i)
    print(patient_path)
    for img in os.listdir(patient_path):
        #print(img)
        complete_path = os.path.join(patient_path, img)
        print(complete_path)
        image = Image.open(complete_path)
        print(image.size)
        plt.imshow(image, cmap='gray')
        plt.show()
# Out:
# /mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/24608
# /mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/24608/891401250.png
# (256, 256)
# /mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/24608/567431455.png
# (256, 256)
# /mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/24608/1305795744.png
# (256, 256)
# /mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/24608/551724896.png
# (256, 256)
# /mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/14814
# /mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/14814/1850400734.png
# (256, 256)
# /mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/14814/345527558.png
# (256, 256)
# /mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/14814/527468376.png
# (256, 256)
# /mnt/storage/breast_cancer_kaggle/images_data/data_png/try_resize/14814/997209934.png
# (256, 256)
# ...

# %%
image_list = os.listdir('/mnt/storage/breast_cancer_kaggle/images_data/original_png/292')
image_list
# Out:
# ['1573200094.png',
#  '38154743.png',
#  '108051053.png',
#  '1957875814.png',
#  '299589511.png']

# %%
for i in image_list:
    image_path = os.path.join('/mnt/storage/breast_cancer_kaggle/images_data/original_png/292', i)
    image = Image.open(image_path)
    print(image.size)
    plt.imshow(image, cmap='gray')
    plt.show()
# Out:
# (2560, 3328)
# (2560, 3328)
# (2560, 3328)
# (2560, 3328)
# (2560, 3328)
